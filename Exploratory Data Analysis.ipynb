# %%
#importing libraries
import pandas as pd
import numpy as np  

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_column', 55)

# %%
#Getting Data
df = pd.read_csv('public_up_to_150k_12_220930.csv')

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4559397800   05/28/2020            353              PPP
# 1  4784467107   04/13/2020            304              PPP
# 2  4939997010   04/04/2020            353              PPP
# 3  5055638002   06/26/2020            353              PPP
# 4  5145117704   05/01/2020            353              PPP
#
#                                   BorrowerName  \
# 0             ARLINGTON CONSULTANTS GROUP, LLC
# 1  ELEVATING EQUIPMENT INSPECTION SERVICE, LLC
# 2                                 SIERRA CORP.
# 3                    BROWNE AND ASSOCIATES LLC
# 4                         BUILT BY BEAVERS LLC
#
#                   BorrowerAddress BorrowerCity BorrowerState BorrowerZip  \
# 0        4601 FAIRFAX DR STE 1200    ARLINGTON            VA  22203-1500
# 1              208 w depot street      BEDFORD            VA  24523-1936
# 2  6723 Whittier Avenue Suite 204      MC LEAN            VA  22101-4509
# 3            1203 Bishopsgate Way       Reston            VA  20194-1407
# 4         5628 MOUNT BURNSIDE WAY        BURKE            VA  22015-2143
#
#   LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  \
# 0     07/17/2021  Paid in Full    24                    100
# 1     04/16/2021  Paid in Full    24                    100
# 2     01/09/2021  Paid in Full    24                    100
# 3     10/28/2021  Paid in Full    60                    100
# 4     09/25/2021  Paid in Full    24                    100
#
#    InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount  \
# 0                85000.0                85000.0                0.0
# 1                85000.0                85000.0                0.0
# 2                85000.0                85000.0                0.0
# 3                85000.0                85000.0                0.0
# 4                85000.0                85000.0                0.0
#
#   FranchiseName  ServicingLenderLocationID  \
# 0           NaN                      73259
# 1           NaN                      73215
# 2           NaN                     122517
# 3           NaN                     123499
# 4           NaN                       9551
#
#                         ServicingLenderName   ServicingLenderAddress  \
# 0                               United Bank       11185 Fairfax Blvd
# 1  American National Bank and Trust Company              628 Main St
# 2                       Atlantic Union Bank  1051 E Cary St, Ste 103
# 3                    BayFirst National Bank       700 Central Avenue
# 4     Bank of America, National Association  100 N Tryon St, Ste 170
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0             FAIRFAX                   VA         22030-5049
# 1            DANVILLE                   VA         24541-1320
# 2            RICHMOND                   VA         23219-4029
# 3    Saint Petersburg                   FL              33701
# 4           CHARLOTTE                   NC         28202-4024
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   R                Y            N
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription ProjectCity ProjectCountyName  \
# 0  Existing or more than 2 years old   ARLINGTON         ARLINGTON
# 1  Existing or more than 2 years old     BEDFORD           BEDFORD
# 2  Existing or more than 2 years old     MC LEAN           FAIRFAX
# 3                         Unanswered      Reston           FAIRFAX
# 4    New Business or 2 years or less       BURKE           FAIRFAX
#
#   ProjectState  ProjectZip     CD  JobsReported  NAICSCode        Race  \
# 0           VA  22203-1500  VA-08           5.0   541618.0  Unanswered
# 1           VA  24523-1936  VA-05          11.0   238290.0  Unanswered
# 2           VA  22101-4509  VA-08           4.0   541513.0  Unanswered
# 3           VA  20194-1407  VA-11           6.0   531210.0  Unanswered
# 4           VA  22015-2143  VA-11           6.0   561990.0       White
#
#            Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  \
# 0  Unknown/NotStated                NaN          85000.0
# 1  Unknown/NotStated                NaN          85000.0
# 2  Unknown/NotStated                NaN          85000.0
# 3  Unknown/NotStated                NaN          85000.0
# 4  Unknown/NotStated                NaN          85000.0
#
#    MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                        NaN           NaN                     NaN
# 1                        NaN           NaN                     NaN
# 2                        NaN           NaN                     NaN
# 3                        NaN           0.0                     NaN
# 4                        NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        73259
# 1  Limited  Liability Company(LLC)                        73215
# 2                      Corporation                       122517
# 3  Limited  Liability Company(LLC)                       188567
# 4              Sole Proprietorship                         9551
#
#                           OriginatingLender OriginatingLenderCity  \
# 0                               United Bank               FAIRFAX
# 1  American National Bank and Trust Company              DANVILLE
# 2                       Atlantic Union Bank              RICHMOND
# 3                  Loan Source Incorporated              NEW YORK
# 4     Bank of America, National Association             CHARLOTTE
#
#   OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                     VA  Unanswered   Unanswered       NaN
# 1                     VA  Unanswered   Unanswered       NaN
# 2                     VA  Unanswered   Unanswered       NaN
# 3                     NY  Unanswered   Unanswered       NaN
# 4                     NC  Male Owned  Non-Veteran       NaN
#
#    ForgivenessAmount ForgivenessDate
# 0           85885.42      06/24/2021
# 1           85774.44      03/16/2021
# 2           81567.00      12/15/2020
# 3           85908.22      08/03/2021
# 4           86054.93      07/29/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599907 entries, 0 to 599906
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599907 non-null  int64
#  1   DateApproved                 599907 non-null  object
#  2   SBAOfficeCode                599907 non-null  int64
#  3   ProcessingMethod             599907 non-null  object
#  4   BorrowerName                 599899 non-null  object
#  5   BorrowerAddress              599901 non-null  object
#  6   BorrowerCity                 599902 non-null  object
#  7   BorrowerState                599907 non-null  object
#  8   BorrowerZip                  599902 non-null  object
#  9   LoanStatusDate               562517 non-null  object
#  10  LoanStatus                   599907 non-null  object
#  11  Term                         599907 non-null  int64
#  12  SBAGuarantyPercentage        599907 non-null  int64
#  13  InitialApprovalAmount        599907 non-null  float64
#  14  CurrentApprovalAmount        599907 non-null  float64
#  15  UndisbursedAmount            599730 non-null  float64
#  16  FranchiseName                8234 non-null    object
#  17  ServicingLenderLocationID    599907 non-null  int64
#  18  ServicingLenderName          599907 non-null  object
#  19  ServicingLenderAddress       599907 non-null  object
#  20  ServicingLenderCity          599907 non-null  object
#  21  ServicingLenderState         599907 non-null  object
#  22  ServicingLenderZip           599907 non-null  object
#  23  RuralUrbanIndicator          599907 non-null  object
#  24  HubzoneIndicator             599907 non-null  object
#  25  LMIIndicator                 599907 non-null  object
#  26  BusinessAgeDescription       599907 non-null  object
#  27  ProjectCity                  599902 non-null  object
#  28  ProjectCountyName            599881 non-null  object
#  29  ProjectState                 599907 non-null  object
#  30  ProjectZip                   599902 non-null  object
#  31  CD                           599888 non-null  object
#  32  JobsReported                 599906 non-null  float64
#  33  NAICSCode                    594602 non-null  float64
#  34  Race                         599907 non-null  object
#  35  Ethnicity                    599907 non-null  object
#  36  UTILITIES_PROCEED            172012 non-null  float64
#  37  PAYROLL_PROCEED              599275 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14763 non-null   float64
#  39  RENT_PROCEED                 21603 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3568 non-null    float64
#  41  HEALTH_CARE_PROCEED          5894 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3754 non-null    float64
#  43  BusinessType                 599844 non-null  object
#  44  OriginatingLenderLocationID  599907 non-null  int64
#  45  OriginatingLender            599907 non-null  object
#  46  OriginatingLenderCity        599907 non-null  object
#  47  OriginatingLenderState       599907 non-null  object
#  48  Gender                       599907 non-null  object
#  49  Veteran                      599907 non-null  object
#  50  NonProfit                    18062 non-null   object
#  51  ForgivenessAmount            564105 non-null  float64
#  52  ForgivenessDate              564105 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 242.6+ MB

# %%
#Checking nulls
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        8
# BorrowerAddress                     6
# BorrowerCity                        5
# BorrowerState                       0
# BorrowerZip                         5
# LoanStatusDate                  37390
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                 177
# FranchiseName                  591673
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              0
# ProjectCity                         5
# ProjectCountyName                  26
# ProjectState                        0
# ProjectZip                          5
# CD                                 19
# JobsReported                        1
# NAICSCode                        5305
# Race                                0
# Ethnicity                           0
# UTILITIES_PROCEED              427895
# PAYROLL_PROCEED                   632
# MORTGAGE_INTEREST_PROCEED      585144
# RENT_PROCEED                   578304
# REFINANCE_EIDL_PROCEED         596339
# HEALTH_CARE_PROCEED            594013
# DEBT_INTEREST_PROCEED          596153
# BusinessType                       63
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# Gender                              0
# Veteran                             0
# NonProfit                      581845
# ForgivenessAmount               35802
# ForgivenessDate                 35802
# dtype: int64

# %%
df = df.loc[df['BorrowerName'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599899 entries, 0 to 599906
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599899 non-null  int64
#  1   DateApproved                 599899 non-null  object
#  2   SBAOfficeCode                599899 non-null  int64
#  3   ProcessingMethod             599899 non-null  object
#  4   BorrowerName                 599899 non-null  object
#  5   BorrowerAddress              599893 non-null  object
#  6   BorrowerCity                 599894 non-null  object
#  7   BorrowerState                599899 non-null  object
#  8   BorrowerZip                  599894 non-null  object
#  9   LoanStatusDate               562510 non-null  object
#  10  LoanStatus                   599899 non-null  object
#  11  Term                         599899 non-null  int64
#  12  SBAGuarantyPercentage        599899 non-null  int64
#  13  InitialApprovalAmount        599899 non-null  float64
#  14  CurrentApprovalAmount        599899 non-null  float64
#  15  UndisbursedAmount            599722 non-null  float64
#  16  FranchiseName                8234 non-null    object
#  17  ServicingLenderLocationID    599899 non-null  int64
#  18  ServicingLenderName          599899 non-null  object
#  19  ServicingLenderAddress       599899 non-null  object
#  20  ServicingLenderCity          599899 non-null  object
#  21  ServicingLenderState         599899 non-null  object
#  22  ServicingLenderZip           599899 non-null  object
#  23  RuralUrbanIndicator          599899 non-null  object
#  24  HubzoneIndicator             599899 non-null  object
#  25  LMIIndicator                 599899 non-null  object
#  26  BusinessAgeDescription       599899 non-null  object
#  27  ProjectCity                  599894 non-null  object
#  28  ProjectCountyName            599873 non-null  object
#  29  ProjectState                 599899 non-null  object
#  30  ProjectZip                   599894 non-null  object
#  31  CD                           599880 non-null  object
#  32  JobsReported                 599898 non-null  float64
#  33  NAICSCode                    594595 non-null  float64
#  34  Race                         599899 non-null  object
#  35  Ethnicity                    599899 non-null  object
#  36  UTILITIES_PROCEED            172011 non-null  float64
#  37  PAYROLL_PROCEED              599267 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14763 non-null   float64
#  39  RENT_PROCEED                 21603 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3568 non-null    float64
#  41  HEALTH_CARE_PROCEED          5894 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3754 non-null    float64
#  43  BusinessType                 599836 non-null  object
#  44  OriginatingLenderLocationID  599899 non-null  int64
#  45  OriginatingLender            599899 non-null  object
#  46  OriginatingLenderCity        599899 non-null  object
#  47  OriginatingLenderState       599899 non-null  object
#  48  Gender                       599899 non-null  object
#  49  Veteran                      599899 non-null  object
#  50  NonProfit                    18062 non-null   object
#  51  ForgivenessAmount            564098 non-null  float64
#  52  ForgivenessDate              564098 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 247.2+ MB

# %%
#Add a few more columns to the Dataframe for Analysis
df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4559397800   05/28/2020            353              PPP
# 1  4784467107   04/13/2020            304              PPP
# 2  4939997010   04/04/2020            353              PPP
# 3  5055638002   06/26/2020            353              PPP
# 4  5145117704   05/01/2020            353              PPP
#
#                                   BorrowerName  \
# 0             ARLINGTON CONSULTANTS GROUP, LLC
# 1  ELEVATING EQUIPMENT INSPECTION SERVICE, LLC
# 2                                 SIERRA CORP.
# 3                    BROWNE AND ASSOCIATES LLC
# 4                         BUILT BY BEAVERS LLC
#
#                   BorrowerAddress BorrowerCity BorrowerState BorrowerZip  \
# 0        4601 FAIRFAX DR STE 1200    ARLINGTON            VA  22203-1500
# 1              208 w depot street      BEDFORD            VA  24523-1936
# 2  6723 Whittier Avenue Suite 204      MC LEAN            VA  22101-4509
# 3            1203 Bishopsgate Way       Reston            VA  20194-1407
# 4         5628 MOUNT BURNSIDE WAY        BURKE            VA  22015-2143
#
#   LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  \
# 0     07/17/2021  Paid in Full    24                    100
# 1     04/16/2021  Paid in Full    24                    100
# 2     01/09/2021  Paid in Full    24                    100
# 3     10/28/2021  Paid in Full    60                    100
# 4     09/25/2021  Paid in Full    24                    100
#
#    InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount  \
# 0                85000.0                85000.0                0.0
# 1                85000.0                85000.0                0.0
# 2                85000.0                85000.0                0.0
# 3                85000.0                85000.0                0.0
# 4                85000.0                85000.0                0.0
#
#   FranchiseName  ServicingLenderLocationID  \
# 0           NaN                      73259
# 1           NaN                      73215
# 2           NaN                     122517
# 3           NaN                     123499
# 4           NaN                       9551
#
#                         ServicingLenderName   ServicingLenderAddress  \
# 0                               United Bank       11185 Fairfax Blvd
# 1  American National Bank and Trust Company              628 Main St
# 2                       Atlantic Union Bank  1051 E Cary St, Ste 103
# 3                    BayFirst National Bank       700 Central Avenue
# 4     Bank of America, National Association  100 N Tryon St, Ste 170
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0             FAIRFAX                   VA         22030-5049
# 1            DANVILLE                   VA         24541-1320
# 2            RICHMOND                   VA         23219-4029
# 3    Saint Petersburg                   FL              33701
# 4           CHARLOTTE                   NC         28202-4024
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   R                Y            N
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  22203-1500  VA-08          5.0
# 1  Existing or more than 2 years old  ...  24523-1936  VA-05         11.0
# 2  Existing or more than 2 years old  ...  22101-4509  VA-08          4.0
# 3                         Unanswered  ...  20194-1407  VA-11          6.0
# 4    New Business or 2 years or less  ...  22015-2143  VA-11          6.0
#
#   NAICSCode        Race          Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 0  541618.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 1  238290.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 2  541513.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 3  531210.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 4  561990.0       White  Unknown/NotStated                NaN         85000.0
#
#   MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                       NaN           NaN                     NaN
# 1                       NaN           NaN                     NaN
# 2                       NaN           NaN                     NaN
# 3                       NaN           0.0                     NaN
# 4                       NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        73259
# 1  Limited  Liability Company(LLC)                        73215
# 2                      Corporation                       122517
# 3  Limited  Liability Company(LLC)                       188567
# 4              Sole Proprietorship                         9551
#
#                           OriginatingLender OriginatingLenderCity  \
# 0                               United Bank               FAIRFAX
# 1  American National Bank and Trust Company              DANVILLE
# 2                       Atlantic Union Bank              RICHMOND
# 3                  Loan Source Incorporated              NEW YORK
# 4     Bank of America, National Association             CHARLOTTE
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      VA  Unanswered   Unanswered       NaN
# 1                      VA  Unanswered   Unanswered       NaN
# 2                      VA  Unanswered   Unanswered       NaN
# 3                      NY  Unanswered   Unanswered       NaN
# 4                      NC  Male Owned  Non-Veteran       NaN
#
#   ForgivenessAmount ForgivenessDate year_approved  month_approved  \
# 0          85885.42      06/24/2021          2020               5
# 1          85774.44      03/16/2021          2020               4
# 2          81567.00      12/15/2020          2020               4
# 3          85908.22      08/03/2021          2020               6
# 4          86054.93      07/29/2021          2020               5
#
#   year_forgiven  month_forgiven
# 0        2021.0             6.0
# 1        2021.0             3.0
# 2        2020.0            12.0
# 3        2021.0             8.0
# 4        2021.0             7.0
#
# [5 rows x 57 columns]

# %%
FirstRound = df.loc[ df['ProcessingMethod'] == 'PPP']

# %%
SecondRound = df.loc[ df['ProcessingMethod'] == 'PPS']

# %%
FirstRound.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  4559397800   05/28/2020            353              PPP
# 1  4784467107   04/13/2020            304              PPP
# 2  4939997010   04/04/2020            353              PPP
# 3  5055638002   06/26/2020            353              PPP
# 4  5145117704   05/01/2020            353              PPP
#
#                                   BorrowerName  \
# 0             ARLINGTON CONSULTANTS GROUP, LLC
# 1  ELEVATING EQUIPMENT INSPECTION SERVICE, LLC
# 2                                 SIERRA CORP.
# 3                    BROWNE AND ASSOCIATES LLC
# 4                         BUILT BY BEAVERS LLC
#
#                   BorrowerAddress BorrowerCity BorrowerState BorrowerZip  \
# 0        4601 FAIRFAX DR STE 1200    ARLINGTON            VA  22203-1500
# 1              208 w depot street      BEDFORD            VA  24523-1936
# 2  6723 Whittier Avenue Suite 204      MC LEAN            VA  22101-4509
# 3            1203 Bishopsgate Way       Reston            VA  20194-1407
# 4         5628 MOUNT BURNSIDE WAY        BURKE            VA  22015-2143
#
#   LoanStatusDate    LoanStatus  Term  SBAGuarantyPercentage  \
# 0     07/17/2021  Paid in Full    24                    100
# 1     04/16/2021  Paid in Full    24                    100
# 2     01/09/2021  Paid in Full    24                    100
# 3     10/28/2021  Paid in Full    60                    100
# 4     09/25/2021  Paid in Full    24                    100
#
#    InitialApprovalAmount  CurrentApprovalAmount  UndisbursedAmount  \
# 0                85000.0                85000.0                0.0
# 1                85000.0                85000.0                0.0
# 2                85000.0                85000.0                0.0
# 3                85000.0                85000.0                0.0
# 4                85000.0                85000.0                0.0
#
#   FranchiseName  ServicingLenderLocationID  \
# 0           NaN                      73259
# 1           NaN                      73215
# 2           NaN                     122517
# 3           NaN                     123499
# 4           NaN                       9551
#
#                         ServicingLenderName   ServicingLenderAddress  \
# 0                               United Bank       11185 Fairfax Blvd
# 1  American National Bank and Trust Company              628 Main St
# 2                       Atlantic Union Bank  1051 E Cary St, Ste 103
# 3                    BayFirst National Bank       700 Central Avenue
# 4     Bank of America, National Association  100 N Tryon St, Ste 170
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0             FAIRFAX                   VA         22030-5049
# 1            DANVILLE                   VA         24541-1320
# 2            RICHMOND                   VA         23219-4029
# 3    Saint Petersburg                   FL              33701
# 4           CHARLOTTE                   NC         28202-4024
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   R                Y            N
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  22203-1500  VA-08          5.0
# 1  Existing or more than 2 years old  ...  24523-1936  VA-05         11.0
# 2  Existing or more than 2 years old  ...  22101-4509  VA-08          4.0
# 3                         Unanswered  ...  20194-1407  VA-11          6.0
# 4    New Business or 2 years or less  ...  22015-2143  VA-11          6.0
#
#   NAICSCode        Race          Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 0  541618.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 1  238290.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 2  541513.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 3  531210.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 4  561990.0       White  Unknown/NotStated                NaN         85000.0
#
#   MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                       NaN           NaN                     NaN
# 1                       NaN           NaN                     NaN
# 2                       NaN           NaN                     NaN
# 3                       NaN           0.0                     NaN
# 4                       NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        73259
# 1  Limited  Liability Company(LLC)                        73215
# 2                      Corporation                       122517
# 3  Limited  Liability Company(LLC)                       188567
# 4              Sole Proprietorship                         9551
#
#                           OriginatingLender OriginatingLenderCity  \
# 0                               United Bank               FAIRFAX
# 1  American National Bank and Trust Company              DANVILLE
# 2                       Atlantic Union Bank              RICHMOND
# 3                  Loan Source Incorporated              NEW YORK
# 4     Bank of America, National Association             CHARLOTTE
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      VA  Unanswered   Unanswered       NaN
# 1                      VA  Unanswered   Unanswered       NaN
# 2                      VA  Unanswered   Unanswered       NaN
# 3                      NY  Unanswered   Unanswered       NaN
# 4                      NC  Male Owned  Non-Veteran       NaN
#
#   ForgivenessAmount ForgivenessDate year_approved  month_approved  \
# 0          85885.42      06/24/2021          2020               5
# 1          85774.44      03/16/2021          2020               4
# 2          81567.00      12/15/2020          2020               4
# 3          85908.22      08/03/2021          2020               6
# 4          86054.93      07/29/2021          2020               5
#
#   year_forgiven  month_forgiven
# 0        2021.0             6.0
# 1        2021.0             3.0
# 2        2020.0            12.0
# 3        2021.0             8.0
# 4        2021.0             7.0
#
# [5 rows x 57 columns]

# %% [markdown]
# # Univariable

# %%
#Count of records in each Processing Method
sns.countplot(df['ProcessingMethod'])
# Out:
# C:\Users\ABDULAZEEZ OLAJUWON\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %%
sns.countplot(df['BorrowerState'])
# Out:
# C:\Users\ABDULAZEEZ OLAJUWON\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BorrowerState', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# C:\Users\ABDULAZEEZ OLAJUWON\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
sns.countplot(df['Ethnicity'])
# Out:
# C:\Users\ABDULAZEEZ OLAJUWON\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
##Rotate the ticklabels
plt.figure(figsize=(15,6)) 
ax = sns.countplot(x="BusinessType", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
plt.show()

# %%
##Rotate the ticklabels
ax = sns.countplot(x="Race", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha='right')
#plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate

# %%
#Plotting Ethnicity Against Loan Status
sns.countplot(x = 'Ethnicity' , hue ='LoanStatus' , data = df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#Cross tabulation
pd.crosstab(df['BorrowerState'],df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# VA                           2756                   39494             139693
# VI                            163                     891               2059
# VT                             74                    4999              14357
# WA                           3666                   40256             127558
# WI                           1763                   47797             120905
# WV                            158                    9507              20287
# WY                            404                    6096              17016

# %%
pd.crosstab(df['year_approved'],df['BorrowerState'])
# Out:
# BorrowerState     VA    VI     VT     WA     WI     WV     WY
# year_approved
# 2020           86752  1864  10785  90871  76660  15687  12161
# 2021           95191  1249   8645  80609  93805  14265  11355

# %%
pd.crosstab(df['LoanStatus'],df['Ethnicity'])
# Out:
# Ethnicity            Hispanic or Latino  Not Hispanic or Latino  \
# LoanStatus
# Active Un-Disbursed                   0                       4
# Exemption 4                         697                    8525
# Paid in Full                       8287                  140511
#
# Ethnicity            Unknown/NotStated
# LoanStatus
# Active Un-Disbursed                  4
# Exemption 4                      28167
# Paid in Full                    413704

# %% [markdown]
# ### Numerical Variables - Discrete Variables

# %%
## Descriptive Summary
df['CurrentApprovalAmount'].describe()
# Out:
# count    599899.000000
# mean      27252.738551
# std       28317.610808
# min           1.800000
# 25%        8600.000000
# 50%       19379.000000
# 75%       33332.000000
# max      149999.990000
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ### Outliers

# %%
sns.boxplot(x = df['CurrentApprovalAmount'])
# Out:
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %%
plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high
sns.boxplot(x="LoanStatus", y="CurrentApprovalAmount", data=df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sns.distplot(df['CurrentApprovalAmount']/10**3)
# Out:
# C:\Users\ABDULAZEEZ OLAJUWON\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CurrentApprovalAmount', ylabel='Density'>

# %%
df['CurrentApprovalAmount'].skew()
# Out:
# 1.95816930830806

# %%
df['CurrentApprovalAmount'].kurt()
# Out:
# 3.8066370099816793

# %%
matrix = df.corr()

# %%
f, ax = plt.subplots(figsize = (15,11))
sns.heatmap(matrix, annot = True)
# Out:
# <AxesSubplot:>
